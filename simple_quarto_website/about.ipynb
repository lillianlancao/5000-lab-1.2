# %% [raw]
# ---
# title: "About"
#
# ---

# %% [markdown]
# About this site

# %% [markdown]
# ##  part1
#
# I like chocolate.
#
#
# ##  part2
#
# I like bubble tea.
#
# ##  part3
#
# I like coffee.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [5, 7, 5, 8, 3]

a = plt.plot(x, y)

print(a)
